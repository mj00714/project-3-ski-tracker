# %%
# This file queries ski resort data from the ski-tracker-master-db (Mongo) and
# uses the lat/long coordinates to collect snow forecast data. Data for American
# ski resorts was collected from the National Weather Service API. Information
# about the API can be found here:
#
# https://www.weather.gov/documentation/services-web-api
#
# Weather for Canadian resorts was collected from xml documents found here:
#
# https://dd.weather.gc.ca/citypage_weather/xml/
#
# Information can about Canadian weather data can be found at:
#
# https://api.weather.gc.ca/
#
# The snow forecast data is then added to the ski resort data pulled from the Mongo
# database. The file then creates a JSON file containing all the data, which can then be read
# by the javascript file to create the map.

# Import required dependencies
from pymongo import MongoClient
from pprint import pprint
from bson import json_util
import requests
import json
import xmltodict

# %%
# Connect to Mongo database and pprint the resorts
mongo = MongoClient(port=27017)
db = mongo['ski-tracker-master-db']
resorts = list(db.resort_master.find())
pprint(resorts)
# Out:
# [{'_id': ObjectId('65aed7c8f3d05baae89cbbdc'),
#   'country': 'US',
#   'location': {'latitude': 48.302353, 'longitude': -117.564011},
#   'name': '49 Degrees North',
#   'pass_type': None,
#   'region': 'WA',
#   'slug': '49-degrees-north',
#   'url': 'https://api.skiapi.com/v1/resort/49-degrees-north'},
#  {'_id': ObjectId('65aed7c8f3d05baae89cbbdd'),
#   'country': 'US',
#   'location': {'latitude': 39.148201, 'longitude': -120.150902},
#   'name': 'Alpine Meadows',
#   'pass_type': None,
#   'region': 'CA',
#   'slug': 'alpine-meadows',
#   'url': 'https://api.skiapi.com/v1/resort/alpine-meadows'},
#  {'_id': ObjectId('65aed7c8f3d05baae89cbbde'),
#   'country': 'US',
#   'location': {'latitude': 40.583828, 'longitude': -111.63726},
#   'name': 'Alta',
#   'pass_type': 'Ikon',
#   'region': 'UT',
#   'slug': 'alta',
#   'url': 'https://api.skiapi.com/v1/resort/alta'},
#  {'_id': ObjectId('65aed7c8f3d05baae89cbbdf'),
#   'country': 'US',
#   'location': {'latitude': 60.961445, 'longitude': -149.102676},
#   'name': 'Alyeska',
#   'pass_type': 'Ikon',
#   'region': 'AK',
#   'slug': 'alyeska',
#   'url': 'https://api.skiapi.com/v1/resort/alyeska'},
#  {'_id': ObjectId('65aed7c8f3d05baae89cbbe0'),
#   'country': 'US',
#   'location': {'latitude': 36.387402, 'longitude': -105.273903},
#   'name': 'Angel Fire',
#   'pass_type': None,
#   'region': 'NM',
#   'slug': 'angel-fire',
#   'url': 'https://api.skiapi.com/v1/resort/angel-fire'},
#  {'_id': ObjectId('65aed7c8f3d05baae89cbbe1'),
#   'country': 'US',
#   'location': {'latitude': 39.642464, 'longitude': -105.871872},
#   'name': 'Arapaho Basin',
#   'pass_type': 'Ikon',
#   'region': 'CO',
#   'slug': 'arapahoe-basin',
#   'url': 'https://api.skiapi.com/v1/resort/arapahoe-basin'},
#  {'_id': ObjectId('65aed7c8f3d05baae89cbbe2'),
#   'country': 'US',
#   'location': {'latitude': 39.182522, 'longitude': -106.855904},
#   'name': 'Aspen Highlands',
#   'pass_type': 'Ikon',
#   'region': 'CO',
#   'slug': 'aspen-highlands',
#   'url': 'https://api.skiapi.com/v1/resort/aspen-highlands'},
#  {'_id': ObjectId('65aed7c8f3d05baae89cbbe3'),
#   'country': 'US',
#   'location': {'latitude': 39.186714, 'longitude': -106.819275},
#   'name': 'Aspen Mountain',
#   'pass_type': 'Ikon',
#   'region': 'CO',
#   'slug': 'aspen-mountain',
#   'url': 'https://api.skiapi.com/v1/resort/aspen-mountain'},
#  {'_id': ObjectId('65aed7c8f3d05baae89cbbe4'),
#   'country': 'US',
#   'location': {'latitude': 44.077778, 'longitude': -71.282776},
#   'name': 'Attitash',
#   'pass_type': 'Epic',
#   'region': 'NH',
#   'slug': 'attitash',
#   'url': 'https://api.skiapi.com/v1/resort/attitash'},
#  {'_id': ObjectId('65aed7c8f3d05baae89cbbe5'),
#   'country': 'US',
#   'location': {'latitude': 39.600464, 'longitude': -106.517899},
#   'name': 'Beaver Creek',
#   'pass_type': 'Epic',
#   'region': 'CO',
#   'slug': 'beavercreek',
#   'url': 'https://api.skiapi.com/v1/resort/beavercreek'},
#  {'_id': ObjectId('65aed7c8f3d05baae89cbbe6'),
#   'country': 'US',
#   'location': {'latitude': 45.283333, 'longitude': -111.401389},
#   'name': 'Big Sky',
#   'pass_type': 'Ikon',
#   'region': 'MT',
#   'slug': 'big-sky',
#   'url': 'https://api.skiapi.com/v1/resort/big-sky'},
#  {'_id': ObjectId('65aed7c8f3d05baae89cbbe7'),
#   'country': 'CA',
#   'location': {'latitude': 49.888, 'longitude': -119.495399},
#   'name': 'Big White',
#   'pass_type': None,
#   'region': 'BC',
#   'slug': 'big-white',
#   'url': 'https://api.skiapi.com/v1/resort/big-white'},
#  {'_id': ObjectId('65aed7c8f3d05baae89cbbe8'),
#   'country': 'CA',
#   'location': {'latitude': 44.50758, 'longitude': -80.316116},
#   'name': 'Blue Mountain',
#   'pass_type': 'Ikon',
#   'region': 'ON',
#   'slug': 'bluemountain',
#   'url': 'https://api.skiapi.com/v1/resort/bluemountain'},
#  {'_id': ObjectId('65aed7c8f3d05baae89cbbe9'),
#   'country': 'US',
#   'location': {'latitude': 44.421673, 'longitude': -72.84948},
#   'name': 'Bolton Valley',
#   'pass_type': None,
#   'region': 'VT',
#   'slug': 'bolton-valley',
#   'url': 'https://api.skiapi.com/v1/resort/bolton-valley'},
#  {'_id': ObjectId('65aed7c8f3d05baae89cbbea'),
#   'country': 'US',
#   'location': {'latitude': 39.316502, 'longitude': -120.270203},
#   'name': 'Boreal',
#   'pass_type': None,
#   'region': 'CA',
#   'slug': 'boreal',
#   'url': 'https://api.skiapi.com/v1/resort/boreal'},
#  {'_id': ObjectId('65aed7c8f3d05baae89cbbeb'),
#   'country': 'US',
#   'location': {'latitude': 39.480724, 'longitude': -106.066238},
#   'name': 'Breckenridge',
#   'pass_type': 'Epic',
#   'region': 'CO',
#   'slug': 'breck',
#   'url': 'https://api.skiapi.com/v1/resort/breck'},
#  {'_id': ObjectId('65aed7c8f3d05baae89cbbec'),
#   'country': 'US',
#   'location': {'latitude': 44.077122, 'longitude': -71.340408},
#   'name': 'Bretton Woods',
#   'pass_type': None,
#   'region': 'NH',
#   'slug': 'brettonwoods',
#   'url': 'https://api.skiapi.com/v1/resort/brettonwoods'},
#  {'_id': ObjectId('65aed7c8f3d05baae89cbbed'),
#   'country': 'US',
#   'location': {'latitude': 37.692753, 'longitude': -112.848129},
#   'name': 'Brian Head',
#   'pass_type': None,
#   'region': 'UT',
#   'slug': 'brianhead',
#   'url': 'https://api.skiapi.com/v1/resort/brianhead'},
#  {'_id': ObjectId('65aed7c8f3d05baae89cbbee'),
#   'country': 'US',
#   'location': {'latitude': 45.817974, 'longitude': -110.89814},
#   'name': 'Bridger Bowl',
#   'pass_type': None,
#   'region': 'MT',
#   'slug': 'bridger-bowl',
#   'url': 'https://api.skiapi.com/v1/resort/bridger-bowl'},
#  {'_id': ObjectId('65aed7c8f3d05baae89cbbef'),
#   'country': 'US',
#   'location': {'latitude': 40.620697, 'longitude': -111.592041},
#   'name': 'Brighton',
#   'pass_type': 'Ikon',
#   'region': 'UT',
#   'slug': 'brighton',
#   'url': 'https://api.skiapi.com/v1/resort/brighton'},
#  {'_id': ObjectId('65aed7c8f3d05baae89cbbf0'),
#   'country': 'US',
#   'location': {'latitude': 43.213402, 'longitude': -72.935013},
#   'name': 'Bromley Mountain',
#   'pass_type': None,
#   'region': 'VT',
#   'slug': 'bromley-mountain',
#   'url': 'https://api.skiapi.com/v1/resort/bromley-mountain'},
#  {'_id': ObjectId('65aed7c8f3d05baae89cbbf1'),
#   'country': 'US',
#   'location': {'latitude': 44.587898, 'longitude': -71.91745},
#   'name': 'Burke Mountain',
#   'pass_type': None,
#   'region': 'VT',
#   'slug': 'burke-mountain',
#   'url': 'https://api.skiapi.com/v1/resort/burke-mountain'},
#  {'_id': ObjectId('65aed7c8f3d05baae89cbbf2'),
#   'country': 'US',
#   'location': {'latitude': 39.206944, 'longitude': -106.860474},
#   'name': 'Buttermilk',
#   'pass_type': 'Ikon',
#   'region': 'CO',
#   'slug': 'buttermilk',
#   'url': 'https://api.skiapi.com/v1/resort/buttermilk'},
#  {'_id': ObjectId('65aed7c8f3d05baae89cbbf3'),
#   'country': 'US',
#   'location': {'latitude': 44.245014, 'longitude': -85.719765},
#   'name': 'Caberfae Peaks',
#   'pass_type': None,
#   'region': 'MI',
#   'slug': 'caberfae-peaks',
#   'url': 'https://api.skiapi.com/v1/resort/caberfae-peaks'},
#  {'_id': ObjectId('65aed7c8f3d05baae89cbbf4'),
#   'country': 'US',
#   'location': {'latitude': 41.051389, 'longitude': -75.355},
#   'name': 'Camelback Mountain',
#   'pass_type': 'Ikon',
#   'region': 'PA',
#   'slug': 'camelback',
#   'url': 'https://api.skiapi.com/v1/resort/camelback'},
#  {'_id': ObjectId('65aed7c8f3d05baae89cbbf5'),
#   'country': 'CA',
#   'location': {'latitude': 51.079722, 'longitude': -114.215833},
#   'name': 'Canada Olympic Park',
#   'pass_type': None,
#   'region': 'AB',
#   'slug': 'canada-olympic-park',
#   'url': 'https://api.skiapi.com/v1/resort/canada-olympic-park'},
#  {'_id': ObjectId('65aed7c8f3d05baae89cbbf6'),
#   'country': 'US',
#   'location': {'latitude': 44.156452, 'longitude': -71.698418},
#   'name': 'Cannon',
#   'pass_type': None,
#   'region': 'NH',
#   'slug': 'cannon',
#   'url': 'https://api.skiapi.com/v1/resort/cannon'},
#  {'_id': ObjectId('65aed7c8f3d05baae89cbbf7'),
#   'country': 'US',
#   'location': {'latitude': 35.562656, 'longitude': -83.090027},
#   'name': 'Cataloochee',
#   'pass_type': None,
#   'region': 'NC',
#   'slug': 'cataloochee',
#   'url': 'https://api.skiapi.com/v1/resort/cataloochee'},
#  {'_id': ObjectId('65aed7c8f3d05baae89cbbf8'),
#   'country': 'US',
#   'location': {'latitude': 37.228348, 'longitude': -119.161705},
#   'name': 'China Peak',
#   'pass_type': None,
#   'region': 'CA',
#   'slug': 'chinapeak',
#   'url': 'https://api.skiapi.com/v1/resort/chinapeak'},
#  {'_id': ObjectId('65aed7c8f3d05baae89cbbf9'),
#   'country': 'IT',
#   'location': {'latitude': 44.933333, 'longitude': 6.75},
#   'name': 'Cesana Claviere',
#   'pass_type': None,
#   'region': 'TO',
#   'slug': 'claviere',
#   'url': 'https://api.skiapi.com/v1/resort/claviere'},
#  {'_id': ObjectId('65aed7c8f3d05baae89cbbfa'),
#   'country': 'US',
#   'location': {'latitude': 39.501125, 'longitude': -106.155998},
#   'name': 'Copper Mountain',
#   'pass_type': 'Ikon',
#   'region': 'CO',
#   'slug': 'copper',
#   'url': 'https://api.skiapi.com/v1/resort/copper'},
#  {'_id': ObjectId('65aed7c8f3d05baae89cbbfb'),
#   'country': 'NZ',
#   'location': {'latitude': -44.926898, 'longitude': 168.736053},
#   'name': 'Coronet Peak',
#   'pass_type': None,
#   'region': 'OTA',
#   'slug': 'coronetpeak',
#   'url': 'https://api.skiapi.com/v1/resort/coronetpeak'},
#  {'_id': ObjectId('65aed7c8f3d05baae89cbbfc'),
#   'country': 'FR',
#   'location': {'latitude': 45.415, 'longitude': 6.6339},
#   'name': 'Courchevel - 3 Vallees',
#   'pass_type': None,
#   'region': 'ARA',
#   'slug': 'courchevel',
#   'url': 'https://api.skiapi.com/v1/resort/courchevel'},
#  {'_id': ObjectId('65aed7c8f3d05baae89cbbfd'),
#   'country': 'US',
#   'location': {'latitude': 44.055382, 'longitude': -71.116783},
#   'name': 'Cranmore',
#   'pass_type': None,
#   'region': 'NH',
#   'slug': 'cranmore-mountain',
#   'url': 'https://api.skiapi.com/v1/resort/cranmore-mountain'},
#  {'_id': ObjectId('65aed7c8f3d05baae89cbbfe'),
#   'country': 'CH',
#   'location': {'latitude': 46.3087, 'longitude': 7.4674},
#   'name': 'Crans-Montana',
#   'pass_type': None,
#   'region': 'VS',
#   'slug': 'cransmontana',
#   'url': 'https://api.skiapi.com/v1/resort/cransmontana'},
#  {'_id': ObjectId('65aed7c8f3d05baae89cbbff'),
#   'country': 'US',
#   'location': {'latitude': 38.899502, 'longitude': -106.964821},
#   'name': 'Crested Butte',
#   'pass_type': 'Epic',
#   'region': 'CO',
#   'slug': 'crested-butte',
#   'url': 'https://api.skiapi.com/v1/resort/crested-butte'},
#  {'_id': ObjectId('65aed7c8f3d05baae89cbc00'),
#   'country': 'US',
#   'location': {'latitude': 46.9459, 'longitude': -121.5802},
#   'name': 'Crystal Mountain',
#   'pass_type': 'Ikon',
#   'region': 'WA',
#   'slug': 'crystal-mountain',
#   'url': 'https://api.skiapi.com/v1/resort/crystal-mountain'},
#  {'_id': ObjectId('65aed7c8f3d05baae89cbc01'),
#   'country': 'CA',
#   'location': {'latitude': 49.37141, 'longitude': -123.19557},
#   'name': 'Cypress Mountain',
#   'pass_type': None,
#   'region': 'BC',
#   'slug': 'cypress-mountain',
#   'url': 'https://api.skiapi.com/v1/resort/cypress-mountain'},
#  {'_id': ObjectId('65aed7c8f3d05baae89cbc02'),
#   'country': 'US',
#   'location': {'latitude': 40.620499, 'longitude': -111.489555},
#   'name': 'Deer Valley',
#   'pass_type': 'Ikon',
#   'region': 'UT',
#   'slug': 'deer-valley',
#   'url': 'https://api.skiapi.com/v1/resort/deer-valley'},
#  {'_id': ObjectId('65aed7c8f3d05baae89cbc03'),
#   'country': 'US',
#   'location': {'latitude': 43.4016, 'longitude': -89.636703},
#   'name': "Devil's Head",
#   'pass_type': None,
#   'region': 'WI',
#   'slug': 'devils-head',
#   'url': 'https://api.skiapi.com/v1/resort/devils-head'},
#  {'_id': ObjectId('65aed7c8f3d05baae89cbc04'),
#   'country': 'US',
#   'location': {'latitude': 39.249599, 'longitude': -119.930199},
#   'name': 'Diamond Peak',
#   'pass_type': None,
#   'region': 'NV',
#   'slug': 'diamondpeak',
#   'url': 'https://api.skiapi.com/v1/resort/diamondpeak'},
#  {'_id': ObjectId('65aed7c8f3d05baae89cbc05'),
#   'country': 'AU',
#   'location': {'latitude': -36.8659, 'longitude': 147.287},
#   'name': 'Falls Creek',
#   'pass_type': None,
#   'region': 'VIC',
#   'slug': 'falls-creek',
#   'url': 'https://api.skiapi.com/v1/resort/falls-creek'},
#  {'_id': ObjectId('65aed7c8f3d05baae89cbc06'),
#   'country': 'IT',
#   'location': {'latitude': 46.284751, 'longitude': 10.828321},
#   'name': 'Folgarida Marilleva',
#   'pass_type': None,
#   'region': 'TN',
#   'slug': 'folgarida-marilleva',
#   'url': 'https://api.skiapi.com/v1/resort/folgarida-marilleva'},
#  {'_id': ObjectId('65aed7c8f3d05baae89cbc07'),
#   'country': 'US',
#   'location': {'latitude': 43.672653, 'longitude': -74.007172},
#   'name': 'Gore Mountain',
#   'pass_type': None,
#   'region': 'NY',
#   'slug': 'gore-mountain',
#   'url': 'https://api.skiapi.com/v1/resort/gore-mountain'},
#  {'_id': ObjectId('65aed7c8f3d05baae89cbc08'),
#   'country': 'US',
#   'location': {'latitude': 43.742401, 'longitude': -111.065201},
#   'name': 'Grand Targhee',
#   'pass_type': None,
#   'region': 'WY',
#   'slug': 'grand-targhee',
#   'url': 'https://api.skiapi.com/v1/resort/grand-targhee'},
#  {'_id': ObjectId('65aed7c8f3d05baae89cbc09'),
#   'country': 'CA',
#   'location': {'latitude': 49.379292, 'longitude': -123.083099},
#   'name': 'Grouse Mountain',
#   'pass_type': None,
#   'region': 'BC',
#   'slug': 'grouse',
#   'url': 'https://api.skiapi.com/v1/resort/grouse'},
#  {'_id': ObjectId('65aed7c8f3d05baae89cbc0a'),
#   'country': 'US',
#   'location': {'latitude': 43.551796, 'longitude': -71.360092},
#   'name': 'Gunstock',
#   'pass_type': None,
#   'region': 'NH',
#   'slug': 'gunstock',
#   'url': 'https://api.skiapi.com/v1/resort/gunstock'},
#  {'_id': ObjectId('65aed7c8f3d05baae89cbc0b'),
#   'country': 'US',
#   'location': {'latitude': 38.936611, 'longitude': -119.939629},
#   'name': 'Heavenly',
#   'pass_type': 'Epic',
#   'region': 'CA',
#   'slug': 'heavenly',
#   'url': 'https://api.skiapi.com/v1/resort/heavenly'},
#  {'_id': ObjectId('65aed7c8f3d05baae89cbc0c'),
#   'country': 'AT',
#   'location': {'latitude': 47.26889038, 'longitude': 11.77694416},
#   'name': 'Hochfügen',
#   'pass_type': None,
#   'region': '7',
#   'slug': 'hochfuegen',
#   'url': 'https://api.skiapi.com/v1/resort/hochfuegen'},
#  {'_id': ObjectId('65aed7c8f3d05baae89cbc0d'),
#   'country': 'US',
#   'location': {'latitude': 39.063099, 'longitude': -120.219498},
#   'name': 'Homewood',
#   'pass_type': None,
#   'region': 'CA',
#   'slug': 'homewood',
#   'url': 'https://api.skiapi.com/v1/resort/homewood'},
#  {'_id': ObjectId('65aed7c8f3d05baae89cbc0e'),
#   'country': 'US',
#   'location': {'latitude': 44.408646, 'longitude': -121.871513},
#   'name': 'Hoodoo',
#   'pass_type': None,
#   'region': 'OR',
#   'slug': 'hoodoo',
#   'url': 'https://api.skiapi.com/v1/resort/hoodoo'},
#  {'_id': ObjectId('65aed7c8f3d05baae89cbc0f'),
#   'country': 'US',
#   'location': {'latitude': 42.205029, 'longitude': -74.20874},
#   'name': 'Hunter Mountain',
#   'pass_type': 'Epic',
#   'region': 'NY',
#   'slug': 'hunter',
#   'url': 'https://api.skiapi.com/v1/resort/hunter'},
#  {'_id': ObjectId('65aed7c8f3d05baae89cbc10'),
#   'country': 'AT',
#   'location': {'latitude': 47.010101, 'longitude': 10.2887},
#   'name': 'Ischgl - Silvretta',
#   'pass_type': None,
#   'region': '7',
#   'slug': 'ischgl-silvretta-arena',
#   'url': 'https://api.skiapi.com/v1/resort/ischgl-silvretta-arena'},
#  {'_id': ObjectId('65aed7c8f3d05baae89cbc11'),
#   'country': 'US',
#   'location': {'latitude': 43.588318, 'longitude': -110.827438},
#   'name': 'Jackson Hole',
#   'pass_type': 'Ikon',
#   'region': 'WY',
#   'slug': 'jackson-hole',
#   'url': 'https://api.skiapi.com/v1/resort/jackson-hole'},
#  {'_id': ObjectId('65aed7c8f3d05baae89cbc12'),
#   'country': 'US',
#   'location': {'latitude': 44.928837, 'longitude': -72.501701},
#   'name': 'Jay Peak',
#   'pass_type': None,
#   'region': 'VT',
#   'slug': 'jay-peak',
#   'url': 'https://api.skiapi.com/v1/resort/jay-peak'},
#  {'_id': ObjectId('65aed7c8f3d05baae89cbc13'),
#   'country': 'US',
#   'location': {'latitude': 42.556477, 'longitude': -73.291328},
#   'name': 'Jiminy Peak',
#   'pass_type': None,
#   'region': 'MA',
#   'slug': 'jiminypeak',
#   'url': 'https://api.skiapi.com/v1/resort/jiminypeak'},
#  {'_id': ObjectId('65aed7c8f3d05baae89cbc14'),
#   'country': 'US',
#   'location': {'latitude': 37.767796, 'longitude': -119.090721},
#   'name': 'June Mountain',
#   'pass_type': 'Ikon',
#   'region': 'CA',
#   'slug': 'june-mountain',
#   'url': 'https://api.skiapi.com/v1/resort/june-mountain'},
#  {'_id': ObjectId('65aed7c8f3d05baae89cbc15'),
#   'country': 'US',
#   'location': {'latitude': 39.605011, 'longitude': -105.953438},
#   'name': 'Keystone',
#   'pass_type': 'Epic',
#   'region': 'CO',
#   'slug': 'keystone',
#   'url': 'https://api.skiapi.com/v1/resort/keystone'},
#  {'_id': ObjectId('65aed7c8f3d05baae89cbc16'),
#   'country': 'US',
#   'location': {'latitude': 43.619675, 'longitude': -72.802879},
#   'name': 'Killington',
#   'pass_type': 'Ikon',
#   'region': 'VT',
#   'slug': 'killington',
#   'url': 'https://api.skiapi.com/v1/resort/killington'},
#  {'_id': ObjectId('65aed7c8f3d05baae89cbc17'),
#   'country': 'US',
#   'location': {'latitude': 43.86063, 'longitude': -71.088127},
#   'name': 'King Pine',
#   'pass_type': None,
#   'region': 'NH',
#   'slug': 'king-pine',
#   'url': 'https://api.skiapi.com/v1/resort/king-pine'},
#  {'_id': ObjectId('65aed7c8f3d05baae89cbc18'),
#   'country': 'US',
#   'location': {'latitude': 38.683231, 'longitude': -120.066856},
#   'name': 'Kirkwood',
#   'pass_type': 'Epic',
#   'region': 'CA',
#   'slug': 'kirkwood',
#   'url': 'https://api.skiapi.com/v1/resort/kirkwood'},
#  {'_id': ObjectId('65aed7c8f3d05baae89cbc19'),
#   'country': 'AT',
#   'location': {'latitude': 47.446602, 'longitude': 12.3908},
#   'name': 'Kitzbühel',
#   'pass_type': None,
#   'region': '7',
#   'slug': 'kitzbuehel',
#   'url': 'https://api.skiapi.com/v1/resort/kitzbuehel'},
#  {'_id': ObjectId('65aed7c8f3d05baae89cbc1a'),
#   'country': 'FR',
#   'location': {'latitude': 45.5064, 'longitude': 6.6772},
#   'name': 'La Plagne',
#   'pass_type': None,
#   'region': 'V',
#   'slug': 'laplagne',
#   'url': 'https://api.skiapi.com/v1/resort/laplagne'},
#  {'_id': ObjectId('65aed7c8f3d05baae89cbc1b'),
#   'country': 'FR',
#   'location': {'latitude': 45.6272, 'longitude': 6.8492},
#   'name': 'La Rosière',
#   'pass_type': None,
#   'region': 'ARA',
#   'slug': 'larosiere',
#   'url': 'https://api.skiapi.com/v1/resort/larosiere'},
#  {'_id': ObjectId('65aed7c8f3d05baae89cbc1c'),
#   'country': 'FR',
#   'location': {'latitude': 45.5722, 'longitude': 6.8288},
#   'name': 'Les Arcs',
#   'pass_type': None,
#   'region': 'ARA',
#   'slug': 'lesarcs',
#   'url': 'https://api.skiapi.com/v1/resort/lesarcs'},
#  {'_id': ObjectId('65aed7c8f3d05baae89cbc1d'),
#   'country': 'FR',
#   'location': {'latitude': 45.3236, 'longitude': 6.5375},
#   'name': 'Les Menuires',
#   'pass_type': None,
#   'region': 'ARA',
#   'slug': 'lesmenuires',
#   'url': 'https://api.skiapi.com/v1/resort/lesmenuires'},
#  {'_id': ObjectId('65aed7c8f3d05baae89cbc1e'),
#   'country': 'US',
#   'location': {'latitude': 44.056583, 'longitude': -71.625809},
#   'name': 'Loon Mountain',
#   'pass_type': 'Ikon',
#   'region': 'NH',
#   'slug': 'loon',
#   'url': 'https://api.skiapi.com/v1/resort/loon'},
#  {'_id': ObjectId('65aed7c8f3d05baae89cbc1f'),
#   'country': 'US',
#   'location': {'latitude': 39.679993, 'longitude': -105.89595},
#   'name': 'Loveland',
#   'pass_type': None,
#   'region': 'CO',
#   'slug': 'loveland',
#   'url': 'https://api.skiapi.com/v1/resort/loveland'},
#  {'_id': ObjectId('65aed7c8f3d05baae89cbc20'),
#   'country': 'US',
#   'location': {'latitude': 44.201653, 'longitude': -72.919006},
#   'name': 'Mad River Glen',
#   'pass_type': None,
#   'region': 'VT',
#   'slug': 'mad-river-glen',
#   'url': 'https://api.skiapi.com/v1/resort/mad-river-glen'},
#  {'_id': ObjectId('65aed7c8f3d05baae89cbc21'),
#   'country': 'IT',
#   'location': {'latitude': 46.231944, 'longitude': 10.826111},
#   'name': 'Madonna di Campiglio',
#   'pass_type': None,
#   'region': '32',
#   'slug': 'madonna-di-campiglio',
#   'url': 'https://api.skiapi.com/v1/resort/madonna-di-campiglio'},
#  {'_id': ObjectId('65aed7c8f3d05baae89cbc22'),
#   'country': 'US',
#   'location': {'latitude': 37.651772, 'longitude': -119.037346},
#   'name': 'Mammoth Mountain',
#   'pass_type': 'Ikon',
#   'region': 'CA',
#   'slug': 'mammoth-lakes',
#   'url': 'https://api.skiapi.com/v1/resort/mammoth-lakes'},
#  {'_id': ObjectId('65aed7c8f3d05baae89cbc23'),
#   'country': 'CA',
#   'location': {'latitude': 49.06906966124412, 'longitude': -120.91434120055804},
#   'name': 'Manning Park',
#   'pass_type': None,
#   'region': 'BC',
#   'slug': 'manning-park',
#   'url': 'https://api.skiapi.com/v1/resort/manning-park'},
#  {'_id': ObjectId('65aed7c8f3d05baae89cbc24'),
#   'country': 'FR',
#   'location': {'latitude': 45.8578, 'longitude': 6.6181},
#   'name': 'Megève',
#   'pass_type': None,
#   'region': 'ARA',
#   'slug': 'megeve',
#   'url': 'https://api.skiapi.com/v1/resort/megeve'},
#  {'_id': ObjectId('65aed7c8f3d05baae89cbc25'),
#   'country': 'FR',
#   'location': {'latitude': 45.3967, 'longitude': 6.5655},
#   'name': 'Meribel',
#   'pass_type': None,
#   'region': 'ARA',
#   'slug': 'meribel',
#   'url': 'https://api.skiapi.com/v1/resort/meribel'},
#  {'_id': ObjectId('65aed7c8f3d05baae89cbc26'),
#   'country': 'US',
#   'location': {'latitude': 38.512714, 'longitude': -106.331696},
#   'name': 'Monarch Mountain',
#   'pass_type': None,
#   'region': 'CO',
#   'slug': 'monarch',
#   'url': 'https://api.skiapi.com/v1/resort/monarch'},
#  {'_id': ObjectId('65aed7c8f3d05baae89cbc27'),
#   'country': 'FR',
#   'location': {'latitude': 44.9316, 'longitude': 6.7219},
#   'name': 'Montgenevre',
#   'pass_type': None,
#   'region': 'PAC',
#   'slug': 'montegenevre',
#   'url': 'https://api.skiapi.com/v1/resort/montegenevre'},
#  {'_id': ObjectId('65aed7c8f3d05baae89cbc28'),
#   'country': 'FR',
#   'location': {'latitude': 46.1789, 'longitude': 6.7089},
#   'name': 'Morzine',
#   'pass_type': None,
#   'region': 'ARA',
#   'slug': 'morzine',
#   'url': 'https://api.skiapi.com/v1/resort/morzine'},
#  {'_id': ObjectId('65aed7c8f3d05baae89cbc29'),
#   'country': 'US',
#   'location': {'latitude': 43.341194, 'longitude': -72.075394},
#   'name': 'Mount Sunapee',
#   'pass_type': 'Epic',
#   'region': 'NH',
#   'slug': 'mount-sunapee',
#   'url': 'https://api.skiapi.com/v1/resort/mount-sunapee'},
#  {'_id': ObjectId('65aed7c8f3d05baae89cbc2a'),
#   'country': 'US',
#   'location': {'latitude': 42.968166, 'longitude': -72.8936},
#   'name': 'Mount Snow',
#   'pass_type': 'Epic',
#   'region': 'VT',
#   'slug': 'mountsnow',
#   'url': 'https://api.skiapi.com/v1/resort/mountsnow'},
#  {'_id': ObjectId('65aed7c8f3d05baae89cbc2b'),
#   'country': 'AU',
#   'location': {'latitude': -37.1462, 'longitude': 146.44982},
#   'name': 'Mount Buller',
#   'pass_type': None,
#   'region': 'VIC',
#   'slug': 'mt-buller',
#   'url': 'https://api.skiapi.com/v1/resort/mt-buller'},
#  {'_id': ObjectId('65aed7c8f3d05baae89cbc2c'),
#   'country': 'AU',
#   'location': {'latitude': -36.9752, 'longitude': 147.1328},
#   'name': 'Mount Hotham',
#   'pass_type': None,
#   'region': 'VIC',
#   'slug': 'mt-hotham',
#   'url': 'https://api.skiapi.com/v1/resort/mt-hotham'},
#  {'_id': ObjectId('65aed7c8f3d05baae89cbc2d'),
#   'country': 'CA',
#   'location': {'latitude': 49.36557060120715, 'longitude': -122.94820807713377},
#   'name': 'Mount Seymour',
#   'pass_type': None,
#   'region': 'BC',
#   'slug': 'mt-seymour',
#   'url': 'https://api.skiapi.com/v1/resort/mt-seymour'},
#  {'_id': ObjectId('65aed7c8f3d05baae89cbc2e'),
#   'country': 'US',
#   'location': {'latitude': 47.921261, 'longitude': -117.096107},
#   'name': 'Mt Spokane',
#   'pass_type': None,
#   'region': 'WA',
#   'slug': 'mt-spokane',
#   'url': 'https://api.skiapi.com/v1/resort/mt-spokane'},
#  {'_id': ObjectId('65aed7c8f3d05baae89cbc2f'),
#   'country': 'US',
#   'location': {'latitude': 44.003559, 'longitude': -121.67865},
#   'name': 'Mount Bachelor',
#   'pass_type': 'Ikon',
#   'region': 'OR',
#   'slug': 'mtbachelor',
#   'url': 'https://api.skiapi.com/v1/resort/mtbachelor'},
#  {'_id': ObjectId('65aed7c8f3d05baae89cbc30'),
#   'country': 'US',
#   'location': {'latitude': 42.540783, 'longitude': -83.811553},
#   'name': 'Mt Brighton',
#   'pass_type': 'Epic',
#   'region': 'MI',
#   'slug': 'mtbrighton',
#   'url': 'https://api.skiapi.com/v1/resort/mtbrighton'},
#  {'_id': ObjectId('65aed7c8f3d05baae89cbc31'),
#   'country': 'US',
#   'location': {'latitude': 34.376888, 'longitude': -117.691544},
#   'name': 'Mountain High',
#   'pass_type': None,
#   'region': 'CA',
#   'slug': 'mthigh',
#   'url': 'https://api.skiapi.com/v1/resort/mthigh'},
#  {'_id': ObjectId('65aed7c8f3d05baae89cbc32'),
#   'country': 'US',
#   'location': {'latitude': 45.331936, 'longitude': -121.665688},
#   'name': 'Mount Hood',
#   'pass_type': None,
#   'region': 'OR',
#   'slug': 'mthood',
#   'url': 'https://api.skiapi.com/v1/resort/mthood'},
#  {'_id': ObjectId('65aed7c8f3d05baae89cbc33'),
#   'country': 'US',
#   'location': {'latitude': 39.3283, 'longitude': -119.878601},
#   'name': 'Mount Rose',
#   'pass_type': None,
#   'region': 'NV',
#   'slug': 'mtrose',
#   'url': 'https://api.skiapi.com/v1/resort/mtrose'},
#  {'_id': ObjectId('65aed7c8f3d05baae89cbc34'),
#   'country': 'JP',
#   'location': {'latitude': 42.8, 'longitude': 140.683333},
#   'name': 'Niseko',
#   'pass_type': 'Ikon',
#   'region': '01',
#   'slug': 'niseko',
#   'url': 'https://api.skiapi.com/v1/resort/niseko'},
#  {'_id': ObjectId('65aed7c8f3d05baae89cbc35'),
#   'country': 'US',
#   'location': {'latitude': 39.275173, 'longitude': -120.122086},
#   'name': 'Northstar',
#   'pass_type': 'Epic',
#   'region': 'CA',
#   'slug': 'northstar',
#   'url': 'https://api.skiapi.com/v1/resort/northstar'},
#  {'_id': ObjectId('65aed7c8f3d05baae89cbc36'),
#   'country': 'US',
#   'location': {'latitude': 43.401806, 'longitude': -72.716705},
#   'name': 'Okemo',
#   'pass_type': 'Epic',
#   'region': 'VT',
#   'slug': 'okemo',
#   'url': 'https://api.skiapi.com/v1/resort/okemo'},
#  {'_id': ObjectId('65aed7c8f3d05baae89cbc37'),
#   'country': 'CA',
#   'location': {'latitude': 45.074642, 'longitude': -72.297806},
#   'name': "Owl's Head",
#   'pass_type': None,
#   'region': 'QC',
#   'slug': 'owlshead',
#   'url': 'https://api.skiapi.com/v1/resort/owlshead'},
#  {'_id': ObjectId('65aed7c8f3d05baae89cbc38'),
#   'country': 'US',
#   'location': {'latitude': 39.196045, 'longitude': -120.233299},
#   'name': 'Palisades Tahoe',
#   'pass_type': 'Ikon',
#   'region': 'CA',
#   'slug': 'palisades',
#   'url': 'https://api.skiapi.com/v1/resort/palisades'},
#  {'_id': ObjectId('65aed7c8f3d05baae89cbc39'),
#   'country': 'US',
#   'location': {'latitude': 40.651375, 'longitude': -111.508118},
#   'name': 'Park City',
#   'pass_type': 'Epic',
#   'region': 'UT',
#   'slug': 'parkcity',
#   'url': 'https://api.skiapi.com/v1/resort/parkcity'},
#  {'_id': ObjectId('65aed7c8f3d05baae89cbc3a'),
#   'country': 'US',
#   'location': {'latitude': 43.180679, 'longitude': -71.833412},
#   'name': 'Pats Peak',
#   'pass_type': None,
#   'region': 'NH',
#   'slug': 'pats-peak',
#   'url': 'https://api.skiapi.com/v1/resort/pats-peak'},
#  {'_id': ObjectId('65aed7c8f3d05baae89cbc3b'),
#   'country': 'AU',
#   'location': {'latitude': -36.4, 'longitude': 148.41},
#   'name': 'Perisher',
#   'pass_type': None,
#   'region': 'NSW',
#   'slug': 'perisher',
#   'url': 'https://api.skiapi.com/v1/resort/perisher'},
#  {'_id': ObjectId('65aed7c8f3d05baae89cbc3c'),
#   'country': 'US',
#   'location': {'latitude': 43.663277, 'longitude': -72.842613},
#   'name': 'Pico Mountain',
#   'pass_type': 'Ikon',
#   'region': 'VT',
#   'slug': 'pico',
#   'url': 'https://api.skiapi.com/v1/resort/pico'},
#  {'_id': ObjectId('65aed7c8f3d05baae89cbc3d'),
#   'country': 'IT',
#   'location': {'latitude': 46.166667, 'longitude': 10.75},
#   'name': 'Pinzolo',
#   'pass_type': None,
#   'region': '32',
#   'slug': 'pinzolo',
#   'url': 'https://api.skiapi.com/v1/resort/pinzolo'},
#  {'_id': ObjectId('65aed7c8f3d05baae89cbc3e'),
#   'country': 'IT',
#   'location': {'latitude': 46.258056, 'longitude': 10.580833},
#   'name': 'Ponte di Legno - Tonale',
#   'pass_type': None,
#   'region': 'BS',
#   'slug': 'pontedilegno-tonale',
#   'url': 'https://api.skiapi.com/v1/resort/pontedilegno-tonale'},
#  {'_id': ObjectId('65aed7c8f3d05baae89cbc3f'),
#   'country': 'US',
#   'location': {'latitude': 43.486305, 'longitude': -71.842003},
#   'name': 'Ragged Mountain',
#   'pass_type': None,
#   'region': 'NH',
#   'slug': 'ragged-mountain',
#   'url': 'https://api.skiapi.com/v1/resort/ragged-mountain'},
#  {'_id': ObjectId('65aed7c8f3d05baae89cbc40'),
#   'country': 'US',
#   'location': {'latitude': 45.191021, 'longitude': -109.335037},
#   'name': 'Red Lodge Mountain',
#   'pass_type': None,
#   'region': 'MT',
#   'slug': 'red-lodge-mountain',
#   'url': 'https://api.skiapi.com/v1/resort/red-lodge-mountain'},
#  {'_id': ObjectId('65aed7c8f3d05baae89cbc41'),
#   'country': 'CA',
#   'location': {'latitude': 49.105343, 'longitude': -117.819099},
#   'name': 'Red Mountain',
#   'pass_type': 'Ikon',
#   'region': 'BC',
#   'slug': 'red-mountain',
#   'url': 'https://api.skiapi.com/v1/resort/red-mountain'},
#  {'_id': ObjectId('65aed7c8f3d05baae89cbc42'),
#   'country': 'US',
#   'location': {'latitude': 44.983387, 'longitude': -70.632965},
#   'name': 'Saddleback',
#   'pass_type': None,
#   'region': 'ME',
#   'slug': 'saddleback',
#   'url': 'https://api.skiapi.com/v1/resort/saddleback'},
#  {'_id': ObjectId('65aed7c8f3d05baae89cbc43'),
#   'country': 'IT',
#   'location': {'latitude': 44.95812, 'longitude': 6.8062},
#   'name': 'Cesana San Sicario',
#   'pass_type': None,
#   'region': '21',
#   'slug': 'sansicario',
#   'url': 'https://api.skiapi.com/v1/resort/sansicario'},
#  {'_id': ObjectId('65aed7c8f3d05baae89cbc44'),
#   'country': 'CA',
#   'location': {'latitude': 49.38000608027801, 'longitude': -121.93556496672508},
#   'name': 'Sasquatch Mountain',
#   'pass_type': None,
#   'region': 'BC',
#   'slug': 'sasquatch-mountain',
#   'url': 'https://api.skiapi.com/v1/resort/sasquatch-mountain'},
#  {'_id': ObjectId('65aed7c8f3d05baae89cbc45'),
#   'country': 'IT',
#   'location': {'latitude': 45.016667, 'longitude': 6.85},
#   'name': "Sauze d'Oulx",
#   'pass_type': None,
#   'region': '21',
#   'slug': 'sauze',
#   'url': 'https://api.skiapi.com/v1/resort/sauze'},
#  {'_id': ObjectId('65aed7c8f3d05baae89cbc46'),
#   'country': 'US',
#   'location': {'latitude': 48.538433, 'longitude': -116.643562},
#   'name': 'Schweitzer',
#   'pass_type': 'Ikon',
#   'region': 'ID',
#   'slug': 'schweitzer',
#   'url': 'https://api.skiapi.com/v1/resort/schweitzer'},
#  {'_id': ObjectId('65aed7c8f3d05baae89cbc47'),
#   'country': 'IT',
#   'location': {'latitude': 44.95, 'longitude': 6.883333},
#   'name': 'Sestriere',
#   'pass_type': None,
#   'region': '21',
#   'slug': 'sestriere',
#   'url': 'https://api.skiapi.com/v1/resort/sestriere'},
#  {'_id': ObjectId('65aed7c8f3d05baae89cbc48'),
#   'country': 'US',
#   'location': {'latitude': 41.03688, 'longitude': -75.078117},
#   'name': 'Shawnee Mountain',
#   'pass_type': None,
#   'region': 'PA',
#   'slug': 'shawnee-mountain',
#   'url': 'https://api.skiapi.com/v1/resort/shawnee-mountain'},
#  {'_id': ObjectId('65aed7c8f3d05baae89cbc49'),
#   'country': 'US',
#   'location': {'latitude': 44.053791, 'longitude': -70.817528},
#   'name': 'Shawnee Peak',
#   'pass_type': None,
#   'region': 'ME',
#   'slug': 'shawnee-peak',
#   'url': 'https://api.skiapi.com/v1/resort/shawnee-peak'},
#  {'_id': ObjectId('65aed7c8f3d05baae89cbc4a'),
#   'country': 'US',
#   'location': {'latitude': 38.792763, 'longitude': -120.090012},
#   'name': 'Sierra at Tahoe',
#   'pass_type': None,
#   'region': 'CA',
#   'slug': 'sierra',
#   'url': 'https://api.skiapi.com/v1/resort/sierra'},
#  {'_id': ObjectId('65aed7c8f3d05baae89cbc4b'),
#   'country': 'CA',
#   'location': {'latitude': 50.438702, 'longitude': -119.208603},
#   'name': 'Silver Star',
#   'pass_type': None,
#   'region': 'BC',
#   'slug': 'silver-star',
#   'url': 'https://api.skiapi.com/v1/resort/silver-star'},
#  {'_id': ObjectId('65aed7c8f3d05baae89cbc4c'),
#   'country': 'US',
#   'location': {'latitude': 44.589092, 'longitude': -72.78833},
#   'name': "Smugglers' Notch",
#   'pass_type': None,
#   'region': 'VT',
#   'slug': 'smuggs',
#   'url': 'https://api.skiapi.com/v1/resort/smuggs'},
#  {'_id': ObjectId('65aed7c8f3d05baae89cbc4d'),
#   'country': 'US',
#   'location': {'latitude': 34.228409, 'longitude': -117.035667},
#   'name': 'Snow Valley',
#   'pass_type': None,
#   'region': 'CA',
#   'slug': 'snow-valley',
#   'url': 'https://api.skiapi.com/v1/resort/snow-valley'},
#  {'_id': ObjectId('65aed7c8f3d05baae89cbc4e'),
#   'country': 'US',
#   'location': {'latitude': 41.214596, 'longitude': -111.859703},
#   'name': 'Snowbasin',
#   'pass_type': 'Ikon',
#   'region': 'UT',
#   'slug': 'snowbasin',
#   'url': 'https://api.skiapi.com/v1/resort/snowbasin'},
#  {'_id': ObjectId('65aed7c8f3d05baae89cbc4f'),
#   'country': 'US',
#   'location': {'latitude': 40.581074, 'longitude': -111.657082},
#   'name': 'Snowbird',
#   'pass_type': 'Ikon',
#   'region': 'UT',
#   'slug': 'snowbird',
#   'url': 'https://api.skiapi.com/v1/resort/snowbird'},
#  {'_id': ObjectId('65aed7c8f3d05baae89cbc50'),
#   'country': 'US',
#   'location': {'latitude': 39.198471, 'longitude': -106.949158},
#   'name': 'Snowmass',
#   'pass_type': 'Ikon',
#   'region': 'CO',
#   'slug': 'snowmass',
#   'url': 'https://api.skiapi.com/v1/resort/snowmass'},
#  {'_id': ObjectId('65aed7c8f3d05baae89cbc51'),
#   'country': 'US',
#   'location': {'latitude': 38.400002, 'longitude': -79.989998},
#   'name': 'Snowshoe Mountain',
#   'pass_type': 'Ikon',
#   'region': 'WV',
#   'slug': 'snowshoe',
#   'url': 'https://api.skiapi.com/v1/resort/snowshoe'},
#  {'_id': ObjectId('65aed7c8f3d05baae89cbc52'),
#   'country': 'AT',
#   'location': {'latitude': 11.0092, 'longitude': 46.9702},
#   'name': 'Sölden',
#   'pass_type': None,
#   'region': '7',
#   'slug': 'soelden',
#   'url': 'https://api.skiapi.com/v1/resort/soelden'},
#  {'_id': ObjectId('65aed7c8f3d05baae89cbc53'),
#   'country': 'US',
#   'location': {'latitude': 40.625648, 'longitude': -111.600708},
#   'name': 'Solitude',
#   'pass_type': 'Ikon',
#   'region': 'UT',
#   'slug': 'solitude',
#   'url': 'https://api.skiapi.com/v1/resort/solitude'},
#  {'_id': ObjectId('65aed7c8f3d05baae89cbc54'),
#   'country': 'AT',
#   'location': {'latitude': 47.127499, 'longitude': 10.264},
#   'name': 'St. Anton Am Arlberg',
#   'pass_type': None,
#   'region': '7',
#   'slug': 'st-anton-am-arlberg',
#   'url': 'https://api.skiapi.com/v1/resort/st-anton-am-arlberg'},
#  {'_id': ObjectId('65aed7c8f3d05baae89cbc55'),
#   'country': 'US',
#   'location': {'latitude': 40.458214, 'longitude': -106.805733},
#   'name': 'Steamboat',
#   'pass_type': 'Ikon',
#   'region': 'CO',
#   'slug': 'steamboat',
#   'url': 'https://api.skiapi.com/v1/resort/steamboat'},
#  {'_id': ObjectId('65aed7c8f3d05baae89cbc56'),
#   'country': 'US',
#   'location': {'latitude': 47.76046, 'longitude': -121.421242},
#   'name': 'Stevens Pass',
#   'pass_type': 'Epic',
#   'region': 'WA',
#   'slug': 'stevens',
#   'url': 'https://api.skiapi.com/v1/resort/stevens'},
#  {'_id': ObjectId('65aed7c8f3d05baae89cbc57'),
#   'country': 'US',
#   'location': {'latitude': 44.530502, 'longitude': -72.786873},
#   'name': 'Stowe',
#   'pass_type': 'Epic',
#   'region': 'VT',
#   'slug': 'stowe',
#   'url': 'https://api.skiapi.com/v1/resort/stowe'},
#  {'_id': ObjectId('65aed7c8f3d05baae89cbc58'),
#   'country': 'US',
#   'location': {'latitude': 43.114017, 'longitude': -72.906303},
#   'name': 'Stratton',
#   'pass_type': 'Ikon',
#   'region': 'VT',
#   'slug': 'stratton',
#   'url': 'https://api.skiapi.com/v1/resort/stratton'},
#  {'_id': ObjectId('65aed7c8f3d05baae89cbc59'),
#   'country': 'US',
#   'location': {'latitude': 39.305447, 'longitude': -120.333206},
#   'name': 'Sugar Bowl',
#   'pass_type': None,
#   'region': 'CA',
#   'slug': 'sugarbowl',
#   'url': 'https://api.skiapi.com/v1/resort/sugarbowl'},
#  {'_id': ObjectId('65aed7c8f3d05baae89cbc5a'),
#   'country': 'US',
#   'location': {'latitude': 44.145721, 'longitude': -72.879318},
#   'name': 'Sugarbush',
#   'pass_type': 'Ikon',
#   'region': 'VT',
#   'slug': 'sugarbush',
#   'url': 'https://api.skiapi.com/v1/resort/sugarbush'},
#  {'_id': ObjectId('65aed7c8f3d05baae89cbc5b'),
#   'country': 'US',
#   'location': {'latitude': 45.06728, 'longitude': -70.315147},
#   'name': 'Sugarloaf',
#   'pass_type': 'Ikon',
#   'region': 'ME',
#   'slug': 'sugarloaf',
#   'url': 'https://api.skiapi.com/v1/resort/sugarloaf'},
#  {'_id': ObjectId('65aed7c8f3d05baae89cbc5c'),
#   'country': 'CA',
#   'location': {'latitude': 50.877369, 'longitude': -119.9132},
#   'name': 'Sun Peaks',
#   'pass_type': 'Ikon',
#   'region': 'BC',
#   'slug': 'sun-peaks',
#   'url': 'https://api.skiapi.com/v1/resort/sun-peaks'},
#  {'_id': ObjectId('65aed7c8f3d05baae89cbc5d'),
#   'country': 'US',
#   'location': {'latitude': 44.550358, 'longitude': -70.907394},
#   'name': 'Sunday River',
#   'pass_type': 'Ikon',
#   'region': 'ME',
#   'slug': 'sunday-river',
#   'url': 'https://api.skiapi.com/v1/resort/sunday-river'},
#  {'_id': ObjectId('65aed7c8f3d05baae89cbc5e'),
#   'country': 'CA',
#   'location': {'latitude': 51.174175, 'longitude': -115.682602},
#   'name': 'Sunshine Village',
#   'pass_type': None,
#   'region': 'AB',
#   'slug': 'sunshine-village',
#   'url': 'https://api.skiapi.com/v1/resort/sunshine-village'},
#  {'_id': ObjectId('65aed7c8f3d05baae89cbc5f'),
#   'country': 'US',
#   'location': {'latitude': 43.709999, 'longitude': -114.339996},
#   'name': 'Sun Valley',
#   'pass_type': 'Ikon',
#   'region': 'ID',
#   'slug': 'sunvalley',
#   'url': 'https://api.skiapi.com/v1/resort/sunvalley'},
#  {'_id': ObjectId('65aed7c8f3d05baae89cbc60'),
#   'country': 'US',
#   'location': {'latitude': 39.354725, 'longitude': -120.257957},
#   'name': 'Tahoe Donner',
#   'pass_type': None,
#   'region': 'CA',
#   'slug': 'tahoe-donner',
#   'url': 'https://api.skiapi.com/v1/resort/tahoe-donner'},
#  {'_id': ObjectId('65aed7c8f3d05baae89cbc61'),
#   'country': 'US',
#   'location': {'latitude': 36.596199, 'longitude': -105.450699},
#   'name': 'Taos Ski Valley',
#   'pass_type': 'Ikon',
#   'region': 'NM',
#   'slug': 'taos',
#   'url': 'https://api.skiapi.com/v1/resort/taos'},
#  {'_id': ObjectId('65aed7c8f3d05baae89cbc62'),
#   'country': 'US',
#   'location': {'latitude': 37.932961, 'longitude': -107.850723},
#   'name': 'Telluride',
#   'pass_type': 'Epic',
#   'region': 'CO',
#   'slug': 'telluride',
#   'url': 'https://api.skiapi.com/v1/resort/telluride'},
#  {'_id': ObjectId('65aed7c8f3d05baae89cbc63'),
#   'country': 'AU',
#   'location': {'latitude': -36.504722, 'longitude': 148.305556},
#   'name': 'Thredbo',
#   'pass_type': None,
#   'region': 'NSW',
#   'slug': 'thredbo',
#   'url': 'https://api.skiapi.com/v1/resort/thredbo'},
#  {'_id': ObjectId('65aed7c8f3d05baae89cbc64'),
#   'country': 'US',
#   'location': {'latitude': 45.33, 'longitude': -121.71},
#   'name': 'Timberline Lodge',
#   'pass_type': None,
#   'region': 'OR',
#   'slug': 'timberline-lodge',
#   'url': 'https://api.skiapi.com/v1/resort/timberline-lodge'},
#  {'_id': ObjectId('65aed7c8f3d05baae89cbc65'),
#   'country': 'CA',
#   'location': {'latitude': 46.213696, 'longitude': -74.584641},
#   'name': 'Mont Tremblant',
#   'pass_type': 'Ikon',
#   'region': 'QB',
#   'slug': 'tremblant',
#   'url': 'https://api.skiapi.com/v1/resort/tremblant'},
#  {'_id': ObjectId('65aed7c8f3d05baae89cbc66'),
#   'country': 'US',
#   'location': {'latitude': 39.605026, 'longitude': -106.356155},
#   'name': 'Vail',
#   'pass_type': 'Epic',
#   'region': 'CO',
#   'slug': 'vail',
#   'url': 'https://api.skiapi.com/v1/resort/vail'},
#  {'_id': ObjectId('65aed7c8f3d05baae89cbc67'),
#   'country': 'IT',
#   'location': {'latitude': 46.56, 'longitude': 11.704722},
#   'name': 'Val Gardena',
#   'pass_type': None,
#   'region': '32',
#   'slug': 'val-gardena',
#   'url': 'https://api.skiapi.com/v1/resort/val-gardena'},
#  {'_id': ObjectId('65aed7c8f3d05baae89cbc68'),
#   'country': 'CH',
#   'location': {'latitude': 46.0935, 'longitude': 7.233},
#   'name': 'Verbier',
#   'pass_type': None,
#   'region': 'VS',
#   'slug': 'verbier',
#   'url': 'https://api.skiapi.com/v1/resort/verbier'},
#  {'_id': ObjectId('65aed7c8f3d05baae89cbc69'),
#   'country': 'US',
#   'location': {'latitude': 43.961613, 'longitude': -71.519989},
#   'name': 'Waterville Valley',
#   'pass_type': None,
#   'region': 'NH',
#   'slug': 'waterville',
#   'url': 'https://api.skiapi.com/v1/resort/waterville'},
#  {'_id': ObjectId('65aed7c8f3d05baae89cbc6a'),
#   'country': 'CA',
#   'location': {'latitude': 50.10693, 'longitude': -122.922073},
#   'name': 'Whistler Blackcomb',
#   'pass_type': 'Epic',
#   'region': 'BC',
#   'slug': 'whistler-blackcomb',
#   'url': 'https://api.skiapi.com/v1/resort/whistler-blackcomb'},
#  {'_id': ObjectId('65aed7c8f3d05baae89cbc6b'),
#   'country': 'US',
#   'location': {'latitude': 44.356506, 'longitude': -73.870613},
#   'name': 'Whiteface',
#   'pass_type': None,
#   'region': 'NY',
#   'slug': 'whiteface',
#   'url': 'https://api.skiapi.com/v1/resort/whiteface'},
#  {'_id': ObjectId('65aed7c8f3d05baae89cbc6c'),
#   'country': 'US',
#   'location': {'latitude': 44.264626, 'longitude': -71.236725},
#   'name': 'Wildcat',
#   'pass_type': 'Epic',
#   'region': 'NH',
#   'slug': 'wildcat',
#   'url': 'https://api.skiapi.com/v1/resort/wildcat'},
#  {'_id': ObjectId('65aed7c8f3d05baae89cbc6d'),
#   'country': 'US',
#   'location': {'latitude': 42.295597, 'longitude': -74.259941},
#   'name': 'Windham Mountain',
#   'pass_type': 'Ikon',
#   'region': 'NY',
#   'slug': 'windham',
#   'url': 'https://api.skiapi.com/v1/resort/windham'},
#  {'_id': ObjectId('65aed7c8f3d05baae89cbc6e'),
#   'country': 'US',
#   'location': {'latitude': 39.891563, 'longitude': -105.764267},
#   'name': 'Winter Park',
#   'pass_type': 'Ikon',
#   'region': 'CO',
#   'slug': 'winter-park',
#   'url': 'https://api.skiapi.com/v1/resort/winter-park'},
#  {'_id': ObjectId('65aed7c8f3d05baae89cbc6f'),
#   'country': 'US',
#   'location': {'latitude': 37.59594, 'longitude': -81.11824},
#   'name': 'Winterplace',
#   'pass_type': None,
#   'region': 'WV',
#   'slug': 'winterplace',
#   'url': 'https://api.skiapi.com/v1/resort/winterplace'}]

# %%
# Define a function that checks whether either of two words are contained in a string. This
# will be used to determine whether snow/flurries are reported in the weather forecast.
def is_word_in_string(word1, word2, input_string):
    return ((word1 in input_string) or (word2 in input_string))

# Use lat/long coordinates to query the weather forecast API for each resort
for resort in resorts:
    lat = round(resort['location']['latitude'], 2)
    long = round(resort['location']['longitude'], 2)

    # First handle the Canadian resorts using the Canadian governemtn xml files
    if resort['country'] == 'CA':

        # Given the name of the resort, assign an appropriate Canadian weather url corresponding to an
        # xml page closest to the resort's lat/long coordinates        
        if resort['slug'] == 'big-white':
            canadian_url = f"https://dd.weather.gc.ca/citypage_weather/xml/BC/s0000772_e.xml"
        elif resort['slug'] == 'bluemountain':
            canadian_url = f"https://dd.weather.gc.ca/citypage_weather/xml/ON/s0000108_e.xml"
        elif resort['slug'] == 'canada-olympic-park':
            canadian_url = f"https://dd.weather.gc.ca/citypage_weather/xml/AB/s0000126_e.xml"
        elif resort['slug'] == 'cypress-mountain':
            canadian_url = f"https://dd.weather.gc.ca/citypage_weather/xml/BC/s0000865_e.xml"
        elif resort['slug'] == 'grouse':
            canadian_url = f"https://dd.weather.gc.ca/citypage_weather/xml/BC/s0000141_e.xml"
        elif resort['slug'] == 'manning-park':
            canadian_url = f"https://dd.weather.gc.ca/citypage_weather/xml/BC/s0000496_e.xml"
        elif resort['slug'] == 'mt-seymour':
            canadian_url = f"https://dd.weather.gc.ca/citypage_weather/xml/BC/s0000373_e.xml"
        elif resort['slug'] == 'owlshead':
            canadian_url = f"https://dd.weather.gc.ca/citypage_weather/xml/QC/s0000345_e.xml"
        elif resort['slug'] == 'red-mountain':
            canadian_url = f"https://dd.weather.gc.ca/citypage_weather/xml/BC/s0000471_e.xml"
        elif resort['slug'] == 'sasquatch':
            canadian_url = f"https://dd.weather.gc.ca/citypage_weather/xml/BC/s0000226_e.xml"
        elif resort['slug'] == 'silver-star':
            canadian_url = f"https://dd.weather.gc.ca/citypage_weather/xml/BC/s0000324_e.xml"
        elif resort['slug'] == 'sun-peaks':
           canadian_url = f"https://dd.weather.gc.ca/citypage_weather/xml/BC/s0000324_e.xml"
        elif resort['slug'] == 'sunshine-village':
            canadian_url = f"https://dd.weather.gc.ca/citypage_weather/xml/AB/s0000404_e.xml"
        elif resort['slug'] == 'tremblant':
            canadian_url = f"https://dd.weather.gc.ca/citypage_weather/xml/QC/s0000213_e.xml"
        elif resort['slug'] == 'whistler-blackcomb':
            canadian_url = f"https://dd.weather.gc.ca/citypage_weather/xml/BC/s0000078_e.xml"

        # Use the Canadian url to request weather data 
        try:
            canadian_data = requests.get(canadian_url).content
            canadian_dict = xmltodict.parse(canadian_data)

            resort['snow_firstperiod'] = is_word_in_string('snow', 'flurries', canadian_dict['siteData']['forecastGroup']['forecast'][1]['textSummary'])
            resort['snow_secondperiod'] = is_word_in_string('snow', 'flurries', canadian_dict['siteData']['forecastGroup']['forecast'][2]['textSummary'])
            resort['snow_thirdperiod'] = is_word_in_string('snow', 'flurries', canadian_dict['siteData']['forecastGroup']['forecast'][3]['textSummary'])
            resort['snow_fourthperiod'] = is_word_in_string('snow', 'flurries', canadian_dict['siteData']['forecastGroup']['forecast'][4]['textSummary'])

            resort['forecast_firstperiod'] = canadian_dict['siteData']['forecastGroup']['forecast'][1]['textSummary']
            resort['forecast_secondperiod'] = canadian_dict['siteData']['forecastGroup']['forecast'][2]['textSummary']
            resort['forecast_thirdperiod'] = canadian_dict['siteData']['forecastGroup']['forecast'][3]['textSummary']
            resort['forecast_fourthperiod'] = canadian_dict['siteData']['forecastGroup']['forecast'][4]['textSummary']

        # Print an error message with the name of each resort that's missing weather forecast data
        except (requests.RequestException, KeyError, IndexError) as e:
            print(f"Error processing api request for {resort['name']}")

    # Next handle American ski resorts using the National Weather Service API
    if resort['country'] == 'US':

        # Query the National Weather Service api to get snowfall data at the lat/long coordinates
        weather_service_url = f"https://api.weather.gov/points/{lat},{long}"
    
        # Query the api for weather data
        try:
            weather_service_data = requests.get(weather_service_url).json()
            forecast_url = weather_service_data['properties']['forecast']
            forecast_data = requests.get(forecast_url).json()

            resort['precip_chance_firstperiod'] = forecast_data['properties']['periods'][0]['probabilityOfPrecipitation']['value']
            resort['precip_chance_secondperiod'] = forecast_data['properties']['periods'][1]['probabilityOfPrecipitation']['value']
            resort['precip_chance_thirdperiod'] = forecast_data['properties']['periods'][2]['probabilityOfPrecipitation']['value']
            resort['precip_chance_fourthperiod'] = forecast_data['properties']['periods'][3]['probabilityOfPrecipitation']['value']

            resort['forecast_firstperiod'] = forecast_data['properties']['periods'][0]['shortForecast']
            resort['forecast_secondperiod'] = forecast_data['properties']['periods'][1]['shortForecast']
            resort['forecast_thirdperiod'] = forecast_data['properties']['periods'][2]['shortForecast']
            resort['forecast_fourthperiod'] = forecast_data['properties']['periods'][3]['shortForecast']

            resort['snow_firstperiod'] = is_word_in_string('Snow', 'Flurries', forecast_data['properties']['periods'][0]['shortForecast'])
            resort['snow_secondperiod'] = is_word_in_string('Snow', 'Flurries', forecast_data['properties']['periods'][1]['shortForecast'])
            resort['snow_thirdperiod'] = is_word_in_string('Snow', 'Flurries', forecast_data['properties']['periods'][2]['shortForecast'])
            resort['snow_fourthperiod'] = is_word_in_string('Snow', 'Flurries', forecast_data['properties']['periods'][3]['shortForecast'])

        # Print an error message with the name of each resort that's missing weather forecast data
        except (requests.RequestException, KeyError, IndexError) as e:
            print(f"Error processing api request for {resort['name']}")
# Out:
# Error processing api request for Alyeska
# Error processing api request for Brighton
# Error processing api request for Cataloochee
# Error processing api request for Cranmore
# Error processing api request for Diamond Peak
# Error processing api request for Gore Mountain
# Error processing api request for Gunstock
# Error processing api request for Hunter Mountain
# Error processing api request for Killington
# Error processing api request for Loveland
# Error processing api request for Mad River Glen
# Error processing api request for Mt Spokane
# Error processing api request for Ragged Mountain
# Error processing api request for Red Lodge Mountain
# Error processing api request for Schweitzer
# Error processing api request for Shawnee Mountain
# Error processing api request for Snow Valley
# Error processing api request for Sugarloaf
# Error processing api request for Sunday River
# Error processing api request for Vail
# Error processing api request for Wildcat
# Error processing api request for Windham Mountain

# %%
# Save all the data to a json file that can be read by resort_plot_logic.js
with open('resort_data.json', 'w') as json_file:
    json.dump(resorts, json_file, default=json_util.default)
